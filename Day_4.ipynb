# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumitha006/Madhumitha-Codeboosters-internship-2026/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = pd.read_csv("SOCR-HeightWeight.csv")

# %%
a.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
x=a[["Height(Inches)"]]

# %%
y=a["Weight(Pounds)"]

# %%
a.isnull()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
a.isnull().any()
# Out:
# Index             False
# Height(Inches)    False
# Weight(Pounds)    False
# dtype: bool

# %%
a.isnull().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#        Height(Inches)
# 8421         69.37021
# 6747         72.07034
# 16809        69.59150
# 7907         69.41584
# 12403        68.46486
# ...               ...
# 11778        66.22392
# 12647        70.39459
# 1952         69.86498
# 10863        70.57890
# 3647         66.96921
#
# [20000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([133.49011676, 130.89093634, 135.94243895, ..., 124.5448634 ,
#        123.53486561, 131.79080591])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.metrics import mean_absolute_error
y_pred=model.predict(x_test)
mean_absolute_error(y_test,y_pred)
# Out:
# 8.038687187511352

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 8.038687187511352

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 101.67129079033418

# %%
r2_score(y_test,y_pred)
# Out:
# 0.24879161436244523

# %%
import joblib

# %%
joblib.dump(model,"linear.pk")
# Out:
# ['linear.pk']
